# %%
from datasets import load_dataset

# %%
import pandas as pd

# %%
dataset=load_dataset("MongoDB/embedded_movies")

# %%
data=pd.DataFrame(dataset["train"])

# %%
data
# Out:
#                                                    plot  runtime  \
# 0     Young Pauline is left a lot of money when her ...    199.0
# 1     A penniless young man tries to save an heiress...     22.0
# 2     Michael "Beau" Geste leaves England in disgrac...    101.0
# 3     Seeking revenge, an athletic young man joins t...     88.0
# 4     An irresponsible young millionaire changes his...     58.0
# ...                                                 ...      ...
# 1495  In the ironically named city of Paradise, a re...    100.0
# 1496  A group of suburban biker wannabes looking for...    100.0
# 1497  Shakespeare's masterpiece "Othello" set in mod...    155.0
# 1498  When a small Colorado town is overrun by the f...     86.0
# 1499  A teenager with teleportation abilities sudden...     88.0
#
#                            genres  \
# 0                        [Action]
# 1         [Comedy, Short, Action]
# 2      [Action, Adventure, Drama]
# 3             [Adventure, Action]
# 4       [Action, Comedy, Romance]
# ...                           ...
# 1495   [Action, Comedy, Thriller]
# 1496  [Action, Adventure, Comedy]
# 1497       [Action, Crime, Drama]
# 1498             [Action, Horror]
# 1499  [Action, Adventure, Sci-Fi]
#
#                                                fullplot  \
# 0     Young Pauline is left a lot of money when her ...
# 1     As a penniless man worries about how he will m...
# 2     Michael "Beau" Geste leaves England in disgrac...
# 3     A nobleman vows to avenge the death of his fat...
# 4     The Uptown Boy, J. Harold Manners (Lloyd) is a...
# ...                                                 ...
# 1495  The story begins with a regular Joe who tries ...
# 1496  Four middle-aged men decide to take a road tri...
# 1497  Advocate Raghunath Mishra has arranged the mar...
# 1498  In Leadville, Colorado, Captain Rhodes and his...
# 1499  David Rice is a high school student in Ann Arb...
#
#                                  directors  \
# 0     [Louis J. Gasnier, Donald MacKenzie]
# 1          [Alfred J. Goulding, Hal Roach]
# 2                         [Herbert Brenon]
# 3                          [Albert Parker]
# 4                             [Sam Taylor]
# ...                                    ...
# 1495                            [Uwe Boll]
# 1496                         [Walt Becker]
# 1497                     [Vishal Bhardwaj]
# 1498                         [Steve Miner]
# 1499                          [Doug Liman]
#
#                                                 writers  \
# 0     [Charles W. Goddard (screenplay), Basil Dickey...
# 1                                [H.M. Walker (titles)]
# 2     [Herbert Brenon (adaptation), John Russell (ad...
# 3     [Douglas Fairbanks (story), Jack Cunningham (a...
# 4     [Ted Wilde (story), John Grey (story), Clyde B...
# ...                                                 ...
# 1495                        [Uwe Boll, Bryan C. Knight]
# 1496                                    [Brad Copeland]
# 1497  [Vishal Bhardwaj (screenplay), Robin Bhatt (sc...
# 1498  [Jeffrey Reddick (screenplay), George A. Romer...
# 1499  [David S. Goyer (screenplay), Jim Uhls (screen...
#
#                    countries  \
# 0                      [USA]
# 1                      [USA]
# 2                      [USA]
# 3                      [USA]
# 4                      [USA]
# ...                      ...
# 1495  [USA, Canada, Germany]
# 1496                   [USA]
# 1497                 [India]
# 1498                   [USA]
# 1499           [USA, Canada]
#
#                                                  poster  \
# 0     https://m.media-amazon.com/images/M/MV5BMzgxOD...
# 1     https://m.media-amazon.com/images/M/MV5BNzE1OW...
# 2                                                  None
# 3     https://m.media-amazon.com/images/M/MV5BMzU0ND...
# 4     https://m.media-amazon.com/images/M/MV5BMTcxMT...
# ...                                                 ...
# 1495  https://m.media-amazon.com/images/M/MV5BMTIzMD...
# 1496  https://m.media-amazon.com/images/M/MV5BZWZlMz...
# 1497  https://m.media-amazon.com/images/M/MV5BY2NmNj...
# 1498  https://m.media-amazon.com/images/M/MV5BNzg1Mj...
# 1499  https://m.media-amazon.com/images/M/MV5BMjEwOT...
#
#                                    languages  \
# 0                                  [English]
# 1                                  [English]
# 2                                  [English]
# 3                                       None
# 4                                  [English]
# ...                                      ...
# 1495                               [English]
# 1496                               [English]
# 1497                                 [Hindi]
# 1498                               [English]
# 1499  [English, Italian, Japanese, Mandarin]
#
#                                                    cast  \
# 0     [Pearl White, Crane Wilbur, Paul Panzer, Edwar...
# 1     [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...
# 2     [Ronald Colman, Neil Hamilton, Ralph Forbes, A...
# 3     [Billie Dove, Tempe Pigott, Donald Crisp, Sam ...
# 4     [Harold Lloyd, Jobyna Ralston, Noah Young, Jim...
# ...                                                 ...
# 1495  [Zack Ward, Dave Foley, Chris Coppola, Jackie ...
# 1496  [Tim Allen, John Travolta, Martin Lawrence, Wi...
# 1497  [Ajay Devgn, Kareena Kapoor, Saif Ali Khan, Ko...
# 1498  [Mena Suvari, Nick Cannon, Michael Welch, Anna...
# 1499  [Hayden Christensen, Jamie Bell, Rachel Bilson...
#
#                       title  num_mflix_comments   rated  \
# 0     The Perils of Pauline                   0    None
# 1        From Hand to Mouth                   0    TV-G
# 2                Beau Geste                   0    None
# 3          The Black Pirate                   1    None
# 4         For Heaven's Sake                   0  PASSED
# ...                     ...                 ...     ...
# 1495                 Postal                   0       R
# 1496              Wild Hogs                   0   PG-13
# 1497                 Omkara                   1    None
# 1498        Day of the Dead                   1       R
# 1499                 Jumper                   0   PG-13
#
#                                                 imdb  \
# 0          {'id': 4465, 'rating': 7.6, 'votes': 744}
# 1         {'id': 10146, 'rating': 7.0, 'votes': 639}
# 2         {'id': 16634, 'rating': 6.9, 'votes': 222}
# 3        {'id': 16654, 'rating': 7.2, 'votes': 1146}
# 4         {'id': 16895, 'rating': 7.6, 'votes': 918}
# ...                                              ...
# 1495   {'id': 486640, 'rating': 4.4, 'votes': 19641}
# 1496   {'id': 486946, 'rating': 5.9, 'votes': 94699}
# 1497    {'id': 488414, 'rating': 8.2, 'votes': 9800}
# 1498   {'id': 489018, 'rating': 4.5, 'votes': 17177}
# 1499  {'id': 489099, 'rating': 6.1, 'votes': 226607}
#
#                                                  awards   type  metacritic  \
# 0       {'nominations': 0, 'text': '1 win.', 'wins': 1}  movie         NaN
# 1     {'nominations': 1, 'text': '1 nomination.', 'w...  movie         NaN
# 2       {'nominations': 0, 'text': '1 win.', 'wins': 1}  movie         NaN
# 3       {'nominations': 0, 'text': '1 win.', 'wins': 1}  movie         NaN
# 4     {'nominations': 1, 'text': '1 nomination.', 'w...  movie         NaN
# ...                                                 ...    ...         ...
# 1495  {'nominations': 3, 'text': '1 win & 3 nominati...  movie        22.0
# 1496  {'nominations': 3, 'text': '3 nominations.', '...  movie        27.0
# 1497  {'nominations': 13, 'text': '14 wins & 13 nomi...  movie         NaN
# 1498  {'nominations': 1, 'text': '1 nomination.', 'w...  movie         NaN
# 1499  {'nominations': 4, 'text': '2 wins & 4 nominat...  movie        35.0
#
#                                          plot_embedding
# 0     [0.0007293965299999999, -0.026834568000000003,...
# 1     [-0.022837115, -0.022941574000000003, 0.014937...
# 2     [0.00023330492999999998, -0.028511643000000003...
# 3     [-0.005927917, -0.033394486, 0.0015323418, -0....
# 4     [-0.0059373598, -0.026604708, -0.0070914757000...
# ...                                                 ...
# 1495  [-0.0121000735, -0.041997142, -0.005094945, -0...
# 1496  [-0.0070759640000000006, -0.021997746000000002...
# 1497  [-0.010883339, -0.016018711, -0.00972983500000...
# 1498  [0.008735137, -0.010910851000000001, 0.0005507...
# 1499  [0.010128586, -0.028155368, -0.0051364526, -0....
#
# [1500 rows x 18 columns]

# %%
data.columns
# Out:
# Index(['plot', 'runtime', 'genres', 'fullplot', 'directors', 'writers',
#        'countries', 'poster', 'languages', 'cast', 'title',
#        'num_mflix_comments', 'rated', 'imdb', 'awards', 'type', 'metacritic',
#        'plot_embedding'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# plot                   27
# runtime                15
# genres                  0
# fullplot               48
# directors              13
# writers                13
# countries               0
# poster                 89
# languages               1
# cast                    1
# title                   0
# num_mflix_comments      0
# rated                 308
# imdb                    0
# awards                  0
# type                    0
# metacritic            928
# plot_embedding         28
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 1471

# %%
data=data.dropna(subset=["fullplot"])

# %%
data
# Out:
#                                                    plot  runtime  \
# 0     Young Pauline is left a lot of money when her ...    199.0
# 1     A penniless young man tries to save an heiress...     22.0
# 2     Michael "Beau" Geste leaves England in disgrac...    101.0
# 3     Seeking revenge, an athletic young man joins t...     88.0
# 4     An irresponsible young millionaire changes his...     58.0
# ...                                                 ...      ...
# 1495  In the ironically named city of Paradise, a re...    100.0
# 1496  A group of suburban biker wannabes looking for...    100.0
# 1497  Shakespeare's masterpiece "Othello" set in mod...    155.0
# 1498  When a small Colorado town is overrun by the f...     86.0
# 1499  A teenager with teleportation abilities sudden...     88.0
#
#                            genres  \
# 0                        [Action]
# 1         [Comedy, Short, Action]
# 2      [Action, Adventure, Drama]
# 3             [Adventure, Action]
# 4       [Action, Comedy, Romance]
# ...                           ...
# 1495   [Action, Comedy, Thriller]
# 1496  [Action, Adventure, Comedy]
# 1497       [Action, Crime, Drama]
# 1498             [Action, Horror]
# 1499  [Action, Adventure, Sci-Fi]
#
#                                                fullplot  \
# 0     Young Pauline is left a lot of money when her ...
# 1     As a penniless man worries about how he will m...
# 2     Michael "Beau" Geste leaves England in disgrac...
# 3     A nobleman vows to avenge the death of his fat...
# 4     The Uptown Boy, J. Harold Manners (Lloyd) is a...
# ...                                                 ...
# 1495  The story begins with a regular Joe who tries ...
# 1496  Four middle-aged men decide to take a road tri...
# 1497  Advocate Raghunath Mishra has arranged the mar...
# 1498  In Leadville, Colorado, Captain Rhodes and his...
# 1499  David Rice is a high school student in Ann Arb...
#
#                                  directors  \
# 0     [Louis J. Gasnier, Donald MacKenzie]
# 1          [Alfred J. Goulding, Hal Roach]
# 2                         [Herbert Brenon]
# 3                          [Albert Parker]
# 4                             [Sam Taylor]
# ...                                    ...
# 1495                            [Uwe Boll]
# 1496                         [Walt Becker]
# 1497                     [Vishal Bhardwaj]
# 1498                         [Steve Miner]
# 1499                          [Doug Liman]
#
#                                                 writers  \
# 3        {'id': 16654, 'rating': 7.2, 'votes': 1146}
# 4         {'id': 16895, 'rating': 7.6, 'votes': 918}
# ...                                              ...
# 1495   {'id': 486640, 'rating': 4.4, 'votes': 19641}
# 1496   {'id': 486946, 'rating': 5.9, 'votes': 94699}
# 1497    {'id': 488414, 'rating': 8.2, 'votes': 9800}
# 1498   {'id': 489018, 'rating': 4.5, 'votes': 17177}
# 1499  {'id': 489099, 'rating': 6.1, 'votes': 226607}
#
#                                                  awards   type  metacritic  \
# 0       {'nominations': 0, 'text': '1 win.', 'wins': 1}  movie         NaN
# 1     {'nominations': 1, 'text': '1 nomination.', 'w...  movie         NaN
# 2       {'nominations': 0, 'text': '1 win.', 'wins': 1}  movie         NaN
# 3       {'nominations': 0, 'text': '1 win.', 'wins': 1}  movie         NaN
# 4     {'nominations': 1, 'text': '1 nomination.', 'w...  movie         NaN
# ...                                                 ...    ...         ...
# 1495  {'nominations': 3, 'text': '1 win & 3 nominati...  movie        22.0
# 1496  {'nominations': 3, 'text': '3 nominations.', '...  movie        27.0
# 1497  {'nominations': 13, 'text': '14 wins & 13 nomi...  movie         NaN
# 1498  {'nominations': 1, 'text': '1 nomination.', 'w...  movie         NaN
# 1499  {'nominations': 4, 'text': '2 wins & 4 nominat...  movie        35.0
#
#                                          plot_embedding
# 0     [0.0007293965299999999, -0.026834568000000003,...
# 1     [-0.022837115, -0.022941574000000003, 0.014937...
# 2     [0.00023330492999999998, -0.028511643000000003...
# 3     [-0.005927917, -0.033394486, 0.0015323418, -0....
# 4     [-0.0059373598, -0.026604708, -0.0070914757000...
# ...                                                 ...
# 1495  [-0.0121000735, -0.041997142, -0.005094945, -0...
# 1496  [-0.0070759640000000006, -0.021997746000000002...
# 1497  [-0.010883339, -0.016018711, -0.00972983500000...
# 1498  [0.008735137, -0.010910851000000001, 0.0005507...
# 1499  [0.010128586, -0.028155368, -0.0051364526, -0....
#
# [1452 rows x 18 columns]

# %%
data=data.drop(columns=["plot_embedding"])

# %%
data.head()
# Out:
#                                                 plot  runtime  \
# 0  Young Pauline is left a lot of money when her ...    199.0
# 1  A penniless young man tries to save an heiress...     22.0
# 2  Michael "Beau" Geste leaves England in disgrac...    101.0
# 3  Seeking revenge, an athletic young man joins t...     88.0
# 4  An irresponsible young millionaire changes his...     58.0
#
#                        genres  \
# 0                    [Action]
# 1     [Comedy, Short, Action]
# 2  [Action, Adventure, Drama]
# 3         [Adventure, Action]
# 4   [Action, Comedy, Romance]
#
#                                             fullplot  \
# 0  Young Pauline is left a lot of money when her ...
# 1  As a penniless man worries about how he will m...
# 2  Michael "Beau" Geste leaves England in disgrac...
# 3  A nobleman vows to avenge the death of his fat...
# 4  The Uptown Boy, J. Harold Manners (Lloyd) is a...
#
#                               directors  \
# 0  [Louis J. Gasnier, Donald MacKenzie]
# 1       [Alfred J. Goulding, Hal Roach]
# 2                      [Herbert Brenon]
# 3                       [Albert Parker]
# 4                          [Sam Taylor]
#
#                                              writers countries  \
# 0  [Charles W. Goddard (screenplay), Basil Dickey...     [USA]
# 1                             [H.M. Walker (titles)]     [USA]
# 2  [Herbert Brenon (adaptation), John Russell (ad...     [USA]
# 3  [Douglas Fairbanks (story), Jack Cunningham (a...     [USA]
# 4  [Ted Wilde (story), John Grey (story), Clyde B...     [USA]
#
#                                               poster  languages  \
# 0  https://m.media-amazon.com/images/M/MV5BMzgxOD...  [English]
# 1  https://m.media-amazon.com/images/M/MV5BNzE1OW...  [English]
# 2                                               None  [English]
# 3  https://m.media-amazon.com/images/M/MV5BMzU0ND...       None
# 4  https://m.media-amazon.com/images/M/MV5BMTcxMT...  [English]
#
#                                                 cast                  title  \
# 0  [Pearl White, Crane Wilbur, Paul Panzer, Edwar...  The Perils of Pauline
# 1  [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...     From Hand to Mouth
# 2  [Ronald Colman, Neil Hamilton, Ralph Forbes, A...             Beau Geste
# 3  [Billie Dove, Tempe Pigott, Donald Crisp, Sam ...       The Black Pirate
# 4  [Harold Lloyd, Jobyna Ralston, Noah Young, Jim...      For Heaven's Sake
#
#    num_mflix_comments   rated                                         imdb  \
# 0                   0    None    {'id': 4465, 'rating': 7.6, 'votes': 744}
# 1                   0    TV-G   {'id': 10146, 'rating': 7.0, 'votes': 639}
# 2                   0    None   {'id': 16634, 'rating': 6.9, 'votes': 222}
# 3                   1    None  {'id': 16654, 'rating': 7.2, 'votes': 1146}
# 4                   0  PASSED   {'id': 16895, 'rating': 7.6, 'votes': 918}
#
#                                               awards   type  metacritic
# 0    {'nominations': 0, 'text': '1 win.', 'wins': 1}  movie         NaN
# 1  {'nominations': 1, 'text': '1 nomination.', 'w...  movie         NaN
# 2    {'nominations': 0, 'text': '1 win.', 'wins': 1}  movie         NaN
# 3    {'nominations': 0, 'text': '1 win.', 'wins': 1}  movie         NaN
# 4  {'nominations': 1, 'text': '1 nomination.', 'w...  movie         NaN

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("thenlper/gte-large")

# %%
def get_embedding(text:str)->list[float]:

    if not text.strip():
        print("attempted to get embedding for empty text.")
        return []
    
    embedding=embedding_model.encode(text)
    return embedding.tolist()

# %%
data["embeding"]=data["fullplot"].apply(get_embedding)

# %%
import pymongo

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://1234:1234@cluster0.intku.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db=client["mongorag"]

# %%
collection=db["mongoragcollection"]

# %%
'''collection.insert_one({
    "name":"muskan",
    "age":25,
    "city":"chandigarh"
})'''
# Out:
# 'collection.insert_one({\n    "name":"muskan",\n    "age":25,\n    "city":"chandigarh"\n})'

# %%
documents=data.to_dict("records")

# %%
collection.insert_many(documents)
# Out:
# InsertManyResult([ObjectId('67d93b1b80ba3433e7194e6f'), ObjectId('67d93b1b80ba3433e7194e70'), ObjectId('67d93b1b80ba3433e7194e71'), ObjectId('67d93b1b80ba3433e7194e72'), ObjectId('67d93b1b80ba3433e7194e73'), ObjectId('67d93b1b80ba3433e7194e74'), ObjectId('67d93b1b80ba3433e7194e75'), ObjectId('67d93b1b80ba3433e7194e76'), ObjectId('67d93b1b80ba3433e7194e77'), ObjectId('67d93b1b80ba3433e7194e78'), ObjectId('67d93b1b80ba3433e7194e79'), ObjectId('67d93b1b80ba3433e7194e7a'), ObjectId('67d93b1b80ba3433e7194e7b'), ObjectId('67d93b1b80ba3433e7194e7c'), ObjectId('67d93b1b80ba3433e7194e7d'), ObjectId('67d93b1b80ba3433e7194e7e'), ObjectId('67d93b1b80ba3433e7194e7f'), ObjectId('67d93b1b80ba3433e7194e80'), ObjectId('67d93b1b80ba3433e7194e81'), ObjectId('67d93b1b80ba3433e7194e82'), ObjectId('67d93b1b80ba3433e7194e83'), ObjectId('67d93b1b80ba3433e7194e84'), ObjectId('67d93b1b80ba3433e7194e85'), ObjectId('67d93b1b80ba3433e7194e86'), ObjectId('67d93b1b80ba3433e7194e87'), ObjectId('67d93b1b80ba3433e7194e88'), ObjectId('67d93b1b
ObjectId('67d93b1b80ba3433e7194ec9'), ObjectId('67d93b1b80ba3433e7194eca'), ObjectId('67d93b1b80ba3433e7194ecb'), ObjectId('67d93b1b80ba3433e7194ecc'), ObjectId('67d93b1b80ba3433e7194ecd'), ObjectId('67d93b1b80ba3433e7194ece'), ObjectId('67d93b1b80ba3433e7194ecf'), ObjectId('67d93b1b80ba3433e7194ed0'), ObjectId('67d93b1b80ba3433e7194ed1'), ObjectId('67d93b1b80ba3433e7194ed2'), ObjectId('67d93b1b80ba3433e7194ed3'), ObjectId('67d93b1b80ba3433e7194ed4'), ObjectId('67d93b1b80ba3433e7194ed5'), ObjectId('67d93b1b80ba3433e7194ed6'), ObjectId('67d93b1b80ba3433e719 ...

# %%
'''
{
  "mappings": {
    "dynamic": true,
    "fields": {
      "embedding": {
        "type": "knnVector",
        "dimensions": 1024,
        "similarity": "cosine"
      }
    }
  }
}
'''
# Out:
# '\n{\n  "mappings": {\n    "dynamic": true,\n    "fields": {\n      "embedding": {\n        "type": "knnVector",\n        "dimensions": 1024,\n        "similarity": "cosine"\n      }\n    }\n  }\n}\n'

# %%
def get_embedding(text:str)->list[float]:

  if not text.strip():
    print("attempted to get embedding for empty text.")
    return []

  embedding=embedding_model.encode(text)
  return embedding.tolist()

# %%
def vector_search(user_query,collection):

  query_embedding=get_embedding(user_query)
  print(query_embedding)

  if query_embedding is None:
    return "Invalid query or embeddig is failed"

  pipeline=[

            {
                "$vectorSearch":{

                "index": "vector_index",
                "queryVector": query_embedding,
                "path": "embedding",
                "numCandidates": 150,  # Number of candidate matches to consider
                "limit": 4,  # Return top 4 matches


                }

            },

              {
                 "$project":{

                "fullplot": 1,  # Include the plot field
                "title": 1,  # Include the title field
                "genres": 1,  # Include the genres field
                "score": {"$meta": "vectorSearchScore"},  # Include the search score
                 }

            }

           ]

  result=collection.aggregate(pipeline)
  return list(result)

# %%
query=vector_search("what is the best horror movie to watch and why?",collection)
# Out:
# [0.019185910001397133, -0.015472973696887493, -0.039554622024297714, 0.0023692885879427195, -0.0026592393405735493, 0.005181845277547836, -0.007513183634728193, 0.04510664567351341, -0.01811216212809086, 0.04297339543700218, 0.013434004038572311, -0.002870751777663827, 0.005479604005813599, -0.031249219551682472, -0.004083319567143917, -0.031060349196195602, -0.041057247668504715, -0.030109725892543793, -0.032163724303245544, 0.0274803563952446, -0.003167578484863043, 0.016843503341078758, -0.04414500296115875, -0.023998111486434937, -0.01558186486363411, 0.017874477431178093, 0.021615177392959595, -0.03042469173669815, 0.04588275030255318, 0.07223064452409744, 0.0023236412089318037, -0.04596633091568947, 0.026177143678069115, -0.048973847180604935, -0.03348347917199135, -0.010094979777932167, 0.05488929525017738, 0.0015838578110560775, -0.0027255306486040354, -0.03803258389234543, 0.016657168045639992, 0.014302327297627926, 0.04556028172373772, -0.011216199956834316, -0.05046370252966881, 0.0023860917426645756, 0.017925577238202095, -0.03008187562227249, -0.007713125087320805, -0.021677715703845024, 0.0025280488189309835, -0.03760182112455368, 0.01106012798845768, 0.006693193688988686, 0.013570702634751797, 0.026865992695093155, -0.011295432224869728, -0.013143101707100868, 0.00019351211085449904, 0.044105056673288345, 0.021538350731134415, -0.021799027919769287, 0.024568943306803703, -0.028306448832154274, 0.015344311483204365, 0.024441946297883987, 0.01056041568517685, -0.030671684071421623, 0.028781568631529808, 0.03318262845277786, 0.019338801503181458, -0.0029937508516013622, -0.019163792952895164, 0.019363807514309883, 0.011445790529251099, 0.020723124966025352, -0.01135885901749134, 0.02779216133058071, -0.015587632544338703, -0.020335908979177475, 0.010521955788135529, 0.05448822304606438, 0.02120736986398697, 0.015374409966170788, -0.07038009911775589, -0.045299988240003586, -0.017124833539128304, 0.02929661050438881, -0.014126746915280819, 0.038227859884500504, 0.035666659474372864, 0.0272141732275486, 0.011118212714791298, -0.03238028660416603, 0.04557008668780327, 0.05568911135196686, -0.03874794766306877, -0.005883847828954458, 0.00319117633625865, -0.017282338812947273, 0.005285186227411032, 0.044459495693445206, -0.004427382722496986, 0.02838730625808239, -0.03157701715826988, -0.005482762586325407, 0.025338752195239067, -0.004885309375822544, -0.024914659559726715, -0.05109066516160965, -0.0074899629689753056, -0.03672900050878525, 0.009195303544402122, 0.010751563124358654, -0.011365892365574837, 0.03295494243502617, -0.004312325268983841, 0.04387519881129265, -0.059020403772592545, 0.023117467761039734, 0.01511061005294323, -0.00029511970933526754, 0.054292403161525726, -0.03185069561004639, 0.05932874232530594, -0.04194684699177742, -0.007042140234261751, 0.03700249642133713, -0.03655995801091194, -0.0068397740833461285, -0.0023263576440513134, -0.029350562021136284, 0.003167265560477972, 0.042417049407958984, 0.017486626282334328, 0.01542280986905098, -0.0034260910470038652, -0.007652462925761938, 0.024394566193223, -0.0518614687025547, 0.042092952877283096, 0.00630158931016922, 0.008150366134941578, 0.07824898511171341, 0.007197114638984203, -0.008467062376439571, 0.018384138122200966, -0.008630874566733837, -0.008001141250133514, 0.03481712564826012, -0.006094435695558786, 0.0023830689024180174, 0.005015678238123655, 0.018067052587866783, -0.013551920652389526, -0.023615283891558647, -0.021410617977380753, 0.02023153565824032, 0.008841213770210743, 0.06210239231586456, 0.040512263774871826, 0.022513320669531822, -0.034654125571250916, 0.03884599730372429, -0.0021718479692935944, 0.04867856949567795, -0.03257758170366287, 0.000907470122911036, -0.009817066602408886, -0.021265942603349686, 0.012817616574466228, 0.004213869106024504, 0.008234712295234203, 0.0016958533087745309, 0.030094845220446587, 0.04801258072257042, 0.048210397362709045, -0.0357104130089283, 0.024411803111433983, 0.04366960749030113, -0 ...

# %%
def get_search_result(query,collection):

  get_knowledge=vector_search(query,collection)

  search_result=""

  for result in get_knowledge:
        search_result += f"Title: {result.get('title', 'N/A')}, Plot: {result.get('fullplot', 'N/A')}\n"

  return search_result

# %%
pipeline = [

    {
        "$vectorSearch": {
            "index": "vector_index",
            "queryVector": "query_embedding",
            "path": "embedding",
            "numCandidates": 150,  # Number of candidate matches to consider
            "limit": 4,  # Return top 4 matches
        }
    },
    {
        "$project": {
            "fullplot": 1,  # Include the plot field
            "title": 1,  # Include the title field
            "genres": 1,  # Include the genres field
            "score": {"$meta": "vectorSearchScore"},  # Include the search score
        }
    }
]

# %%
print("The End")
